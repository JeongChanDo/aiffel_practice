# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import dlib

# %% [markdown]
# # read image and show

# %%
my_img_path = os.getenv("HOME")+"/aiffel/camera_sticker/images/image.jpg"
img_bgr = cv2.imread(my_img_path)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
img_show = img_rgb.copy()
plt.imshow(img_rgb)

# %% [markdown]
# # find face using hog feature with dlib

# %%
detector_hog = dlib.get_frontal_face_detector()
face_img = img_show.copy()
dlib_rects = detector_hog(img_rgb, 1)
print(dlib_rects)
for dlib_rect in dlib_rects:
    left = dlib_rect.left()
    top = dlib_rect.top()
    right = dlib_rect.right()
    bottom = dlib_rect.bottom()
    cv2.rectangle(face_img, (left, top), (right, bottom), (0, 255, 0), 2)

plt.imshow(face_img)
# Out:
# rectangles[[(230, 142) (498, 409)]]

# %% [markdown]
# # landmark estimation using dlib's pretrained model
# - find 68 face landmarks for attaching srickers
# - we use pretrained model based on regression tree from dlib

# %%
model_path = "models/shape_predictor_68_face_landmarks.dat"
landmark_predictor = dlib.shape_predictor(model_path)
feature_img = img_show.copy()

list_landmarks = []
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

print(len(list_landmarks[0]))

for landmark in list_landmarks:
    for idx, point in enumerate(list_points):
        cv2.circle(feature_img, point, 2, (0, 255, 255), -1) # yellow

plt.imshow(feature_img)
plt.show()
# Out:
# 68

# %% [markdown]
# # attach cat whisker
# - find nose location using landmark
# - attach cat whisker to our face

# %%
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[30]) # nose center index : 30
    x = landmark[30][0]
    y = landmark[30][1] - dlib_rect.width()//2
    w = dlib_rect.width() // 2
    h = dlib_rect.width() // 2
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))
# Out:
# (362, 284)
# (x,y) : (362,150)
# (w,h) : (134,134)

# %%
sticker_path = 'cat-whiskers.png'
img_sticker = cv2.imread(sticker_path)
img_sticker = cv2.resize(img_sticker, (w,h))
plt.imshow(img_sticker)
print (img_sticker.shape)
# Out:
# (134, 134, 3)

# %%
refined_x = x - w // 2  # left
refined_y = y + h // 2  # top
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (x,y) : (295,217)

# %%
"""
img_sticker = img_sticker[-refined_y:]
print (img_sticker.shape)
plt.imshow(img_sticker)
"""
# Out:
# '\nimg_sticker = img_sticker[-refined_y:]\nprint (img_sticker.shape)\nplt.imshow(img_sticker)\n'

# %%
print(refined_y)
print(img_sticker.shape[0])
print(refined_x)
print(refined_x + img_sticker.shape[1])
img_cat = img_show.copy()
sticker_area = img_show[refined_y:refined_y + img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
plt.imshow(sticker_area)
img_cat[refined_y:refined_y + img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
    np.where(img_sticker==255,sticker_area,img_sticker).astype(np.uint8)
# Out:
# 217
# 134
# 295
# 429

# %%
plt.subplot(2,1,1)
plt.imshow(sticker_area)
plt.subplot(2,1,2)
plt.imshow(img_sticker)
print(img_sticker.shape)
print(img_sticker[0, 0, :])
print(np.where(img_sticker == 255))
# Out:
# (134, 134, 3)
# [255 255 255]
# (array([  0,   0,   0, ..., 133, 133, 133]), array([  0,   0,   0, ..., 133, 133, 133]), array([0, 1, 2, ..., 0, 1, 2]))

# %%
plt.imshow(img_cat)

# %% [markdown]
# ## add weighted img

# %%
alpha = 0.5
beta = (1.0 - alpha)
res = cv2.addWeighted(sticker_area, alpha, img_sticker, beta, 0.0)
plt.figure(figsize=(6, 12))
plt.subplot(1, 2, 1)
plt.imshow(res)

res = np.where(img_sticker==255,sticker_area,cv2.addWeighted(sticker_area, alpha, img_sticker, beta, 0.0)).astype(np.uint8)
plt.subplot(1, 2, 2)
plt.imshow(res)

# %%
img_weighted = img_show.copy()
img_weighted[refined_y:refined_y + img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
    np.where(img_sticker==255,sticker_area,cv2.addWeighted(sticker_area, alpha, img_sticker, beta, 0.0)).astype(np.uint8)
plt.imshow(img_weighted)
